# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_csv('LCK_SummerPlayoffs_2024.csv', delimiter=';')
df = df.drop(columns=['Date', 'Round', 'Day', 'Patch', 'Stage', 'No Game', 'all Games', 'Format', 'Game of day', 'Side', 'Time', 'Ban', 'Ban Opponent', 'Pick Opponent', 'Pick'])
df.head()
# Out:
#       Player     Role Team Opponent Team Opponent Player Champion  \
# 0     kingen      TOP   DK           FOX           Clear   Rumble
# 1      Lucid   JUNGLE   DK           FOX          Raptor    Ivern
# 2  ShowMaker      MID   DK           FOX          Clozer    Nasus
# 3     Aiming  ADCARRY   DK           FOX            Hena  Smolder
# 4      Moham  SUPPORT   DK           FOX            Duro     Rell
#
#   Champion Opponent Outcome  Kills Team  Turrets Team  ...  \
# 0              Ornn     Win          12             9  ...
# 1          Xin_Zhao     Win          12             9  ...
# 2              Azir     Win          12             9  ...
# 3              Ashe     Win          12             9  ...
# 4         Seraphine     Win          12             9  ...
#
#    Damage self mitigated  Total Damage Shielded On Teammates  \
# 0                  19400                                   0
# 1                  12800                                8507
# ...

# %%
df.to_excel('LCK_SummerPlayoffs_2024_cleaned.xlsx', index=False)
